# %% [markdown]
# <a href="https://colab.research.google.com/github/ob3x/Learn-Ds/blob/main/Untitled33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
np.set_printoptions(precision=6, suppress=True, edgeitems=30, linewidth=120, formatter=dict(float=lambda x: f"{x:.2f}"))
sns.set(font_scale=1.3)
sklearn.__version__
# Out:
# '1.6.1'

# %%
from sklearn.datasets import make_regression

data, target = make_regression(n_samples=100, n_features=1, n_targets=1, noise=30, random_state=42)

print(f"Data shape: {data.shape}")
print(f"Target shape: {target.shape}")
# Out:
# Data shape: (100, 1)
# Target shape: (100,)

# %%
data[:5]
# Out:
# array([[0.93],
#        [0.09],
#        [-1.06],
#        [0.31],
#        [-0.48]])

# %%
target[:5]
# Out:
# array([74.59, -37.46, -16.46, 5.35, -13.21])

# %%
plt.figure(figsize=(8,6))
plt.title("Regresja liniowa")
plt.xlabel("cecha x")
plt.ylabel("zmienna docelowa")
plt.scatter(data, target, c="b")
plt.legend()
plt.plot()
# Out:
# /tmp/ipykernel_4054/3550950414.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# []

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(data, target)
# Out:
# LinearRegression()

# %%
model.score(data, target)
# Out:
# 0.7426670084336404

# %%
y_pred = model.predict(data)

y_pred
# Out:
# array([49.90, 7.83, -49.21, 19.15, -20.38, 35.77, -19.60, 30.53, 33.97, 53.50, 44.45, 80.13, 40.29, -7.45, -36.79,
#        8.07, -94.15, 29.07, 54.87, -127.04, 28.25, 8.33, -19.71, 49.11, 81.46, 76.53, -26.43, 1.71, -26.49, -56.11,
#        21.29, 22.22, 16.50, -22.90, -41.75, 13.30, -11.40, 21.52, 44.48, -11.04, 21.50, -30.24, 79.39, -22.33, -8.17,
#        -16.04, -11.51, -28.65, 19.88, 13.90, -12.83, 3.75, -8.17, 77.14, -15.69, 20.62, 20.00, -5.76, -8.19, -95.54,
#        19.64, -7.75, -51.63, -31.49, -69.43, 51.76, -82.46, -91.84, -24.52, 41.74, 43.98, -66.88, -70.18, -57.34,
#        -38.32, 82.19, 52.11, 15.55, 18.25, -23.63, -84.36, 9.02, 12.03, -62.69, 56.17, -2.27, -19.90, 2.82, -46.97,
#        -3.39, -53.86, 71.08, 6.86, -21.51, -19.46, 95.79, -67.50, -32.37, -0.09, -11.91])

# %%
plt.figure(figsize=(8,6))
plt.title("Regresja liniowa")
plt.xlabel("cecha x")
plt.ylabel("zmienna docelowa")
plt.scatter(data, target, label="cecha x")
plt.plot(data, y_pred, color="r", label="model")
plt.legend()
plt.plot()
# Out:
# []

# %%
model.score(data, target)
# Out:
# 0.7426670084336404

# %%
model.coef_
# Out:
# array([49.83])

# %%
model.intercept_
# Out:
# np.float64(3.4953459615809184)

# %%
plt.figure(figsize=(8,6))
plt.title("regresja liniowa")
plt.xlabel("cecha x")
plt.ylabel("cecha y")
plt.scatter(data, target, label="cecha x")
plt.plot(data, model.intercept_ + model.coef_[0]*data, c="r", label="model")
plt.legend()
plt.show()

# %%
data, target = make_regression(n_samples=1000, n_features=1, n_targets=1, noise=15.0, random_state=42)
print(f"Data shape: {data.shape}")
print(f"Target shape: {target.shape}")
# Out:
# Data shape: (1000, 1)
# Target shape: (1000,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(data, target, test_size=0.25)

print(f"X_train shape: {X_train.shape}")
print(f"Y_train shape: {Y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"Y_test shape: {Y_test.shape}")
# Out:
# X_train shape: (750, 1)
# Y_train shape: (750,)
# X_test shape: (250, 1)
# Y_test shape: (250,)

# %%
plt.figure(figsize=(8, 6))
plt.title("Dane testowe vs dane treningowe")
plt.xlabel("Cecha x")
plt.ylabel("cecha docelowa")
plt.scatter(X_train, Y_train, c="b", label="zbiór treningowy", alpha=0.5)
plt.scatter(X_test, Y_test, c="r", label="zbiór testowy", alpha=0.5)
plt.legend()
plt.plot()
# Out:
# []

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train, Y_train)
# Out:
# 0.5408930484049115

# %%
model.score(X_test, Y_test)
# Out:
# 0.5502380687566506

# %%
plt.figure(figsize=(8,6))
plt.title("regresja liniowa zbiór treningowy")
plt.xlabel("cecha x")
plt.ylabel("zmienna docelowa")
plt.scatter(X_train, Y_train, label="zbiór treningowy", c="g", alpha=0.5)
plt.plot(X_train, model.intercept_ + model.coef_*X_train, c="r")
plt.legend()
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8,6))
plt.title("regresja liniowa zbiór testowy")
plt.xlabel("cecha x")
plt.ylabel("zmienna docelowa")
plt.scatter(X_test, Y_test, label="zbiór testowy", c="g", alpha=0.5)
plt.plot(X_test, model.intercept_ + model.coef_*X_test, c="r")
plt.legend()
plt.plot()
# Out:
# []

# %%
y_pred = model.predict(X_test)

predictions = pd.DataFrame(data={"y_true" : Y_test, "y_pred" : y_pred})
predictions.head()
# Out:
#       y_true     y_pred
# 0  -5.602081 -12.767885
# 1   6.816964  -9.120373
# 2  -0.869617   8.604327
# 3  -0.390419  -4.546477
# 4  24.961278  11.889108

# %%
_ = predictions["error"] = predictions["y_true"] - predictions["y_pred"]

# %%
predictions.head()
# Out:
#       y_true     y_pred      error
# 0  -5.602081 -12.767885   7.165805
# 1   6.816964  -9.120373  15.937337
# 2  -0.869617   8.604327  -9.473944
# 3  -0.390419  -4.546477   4.156058
# 4  24.961278  11.889108  13.072170

# %%
_ = predictions["error"].plot(kind="hist", bins=50, figsize=(8, 6))
